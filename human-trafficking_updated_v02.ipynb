# %%
# Dependencies and Setup
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
from IPython.display import display,HTML
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math
from prettypandas import PrettyPandas
sns.set_style("ticks")
sns.set_context(context="notebook",font_scale=1)

# %% [markdown]
# ### Importing CSV's

# %%
# Read CSV
#2013 UK
competent_authority_df_2013_uk = pd.read_csv("uk-human-trafficking-data/2013_competent_authority.csv")
country_of_referral_df_2013_uk = pd.read_csv("uk-human-trafficking-data/2013_country_of_referral.csv")
exploitation_type_df_2013_uk = pd.read_csv("uk-human-trafficking-data/2013_exploitation_type.csv")
referrals_adult_df_2013_uk = pd.read_csv("uk-human-trafficking-data/2013_referrals_adult.csv")
referrals_all_df_2013_uk = pd.read_csv("uk-human-trafficking-data/2013_referrals_all.csv")
referrals_minor_df_2013_uk = pd.read_csv("uk-human-trafficking-data/2013_referrals_minor.csv")
referring_agency_df_2013_uk = pd.read_csv("uk-human-trafficking-data/2013_referring_agency.csv")

#2014 UK
competent_authority_df_2014_uk = pd.read_csv("uk-human-trafficking-data/2014_competent_authority.csv")
country_of_referral_df_2014_uk = pd.read_csv("uk-human-trafficking-data/2014_country_of_referral.csv")
exploitation_type_df_2014_uk = pd.read_csv("uk-human-trafficking-data/2014_exploitation_type.csv")
referrals_adult_df_2014_uk = pd.read_csv("uk-human-trafficking-data/2014_referrals_adult.csv")
referrals_all_df_2014_uk = pd.read_csv("uk-human-trafficking-data/2014_referrals_all.csv")
referrals_minor_df_2014_uk = pd.read_csv("uk-human-trafficking-data/2014_referrals_minor.csv")
referring_agency_df_2014_uk = pd.read_csv("uk-human-trafficking-data/2014_referring_agency.csv")

#2015 UK
competent_authority_df_2015_uk = pd.read_csv("uk-human-trafficking-data/2015_competent_authority.csv")
country_of_referral_df_2015_uk = pd.read_csv("uk-human-trafficking-data/2015_country_of_referral.csv")
exploitation_type_df_2015_uk = pd.read_csv("uk-human-trafficking-data/2015_exploitation_type.csv")
referrals_adult_df_2015_uk = pd.read_csv("uk-human-trafficking-data/2015_referrals_adult.csv")
referrals_all_df_2015_uk = pd.read_csv("uk-human-trafficking-data/2015_referrals_all.csv")
referrals_minor_df_2015_uk = pd.read_csv("uk-human-trafficking-data/2015_referrals_minor.csv")
referring_agency_df_2015_uk = pd.read_csv("uk-human-trafficking-data/2015_referring_agency.csv")

#2016 UK
competent_authority_df_2016_uk = pd.read_csv("uk-human-trafficking-data/2016_competent_authority.csv")
country_of_referral_df_2016_uk = pd.read_csv("uk-human-trafficking-data/2016_country_of_referral.csv")
exploitation_type_df_2016_uk = pd.read_csv("uk-human-trafficking-data/2016_exploitation_type.csv")
referrals_adult_df_2016_uk = pd.read_csv("uk-human-trafficking-data/2016_referrals_adult.csv")
referrals_all_df_2016_uk = pd.read_csv("uk-human-trafficking-data/2016_referrals_all.csv")
referrals_minor_df_2016_uk = pd.read_csv("uk-human-trafficking-data/2016_referrals_minor.csv")
referring_agency_df_2016_uk = pd.read_csv("uk-human-trafficking-data/2016_referring_agency.csv")

#2013 USA
eports_of_arrestees_for_human_trafficking_by_age_and_sex_2013_usa = pd.read_csv("ucr-human-trafficking-2013/data/reports_of_arrestees_for_human_trafficking_by_age_and_sex_2013.csv")
reports_of_offenses_of_human_trafficking_2013_usa = pd.read_csv("ucr-human-trafficking-2013/data/reports_of_offenses_of_human_trafficking_2013.csv")
state_participation_in_the_ucr_human_trafficking_data_collection_2013_usa = pd.read_csv("ucr-human-trafficking-2013/data/state_participation_in_the_ucr_human_trafficking_data_collection_2013.csv")

#2014 USA
tbl01_df_2014_usa = pd.read_csv("ucr-human-trafficking-2014/data/14tbl01.csv")
tbl02_df_2014_usa = pd.read_csv("ucr-human-trafficking-2014/data/14tbl02.csv")
tbl03_df_2014_usa = pd.read_csv("ucr-human-trafficking-2014/data/14tbl03.csv")
tbl04_df_2014_usa = pd.read_csv("ucr-human-trafficking-2014/data/14tbl04.csv")
tbl05_df_2014_usa = pd.read_csv("ucr-human-trafficking-2014/data/14tbl05.csv")

#2015 USA
tbl01_df_2015_usa = pd.read_csv("ucr-human-trafficking-2015/data/16tbl01.csv")
tbl02_df_2015_usa = pd.read_csv("ucr-human-trafficking-2015/data/16tbl02.csv")
tbl03_df_2015_usa = pd.read_csv("ucr-human-trafficking-2015/data/16tbl03.csv")
tbl04_df_2015_usa = pd.read_csv("ucr-human-trafficking-2015/data/16tbl04.csv")

#2016 USA
tbl01_df_2016_usa = pd.read_csv("ucr-human-trafficking-2016/data/16tbl01.csv")
tbl02_df_2016_usa = pd.read_csv("ucr-human-trafficking-2016/data/16tbl02.csv")
tbl03_df_2016_usa = pd.read_csv("ucr-human-trafficking-2016/data/16tbl03.csv")
tbl04_df_2016_usa = pd.read_csv("ucr-human-trafficking-2016/data/16tbl04.csv")

# %% [markdown]
# ### Data Cleaning

# %%
#update Column names 2014 USA
tbl02_df_2014_usa.rename(columns={'column_a': 'State', 'offenses': 'offenses_Commercial_sex_act', 
                                  'total_cleared': 'total_cleared_Commercial_sex_act', 'clearances_under_18': 'clearances_under_18_Commercial_sex_act', 
                                  'offenses_2': 'offenses_Involuntary_servitude', 'total_cleared_2': 'total_cleared_Involuntary_servitude', 
                                  'clearances_under_18_2': 'clearances_under_18_Involuntary_servitude', 'offenses_3': 'offenses_total', 
                                  'total_cleared_3': 'total_cleared_total', 'clearances_under_18_3': 'clearances_under_18_total'}, inplace=True)
tbl03_df_2014_usa.rename(columns={'column_a': 'State', 'column_b': 'Offense', 'column_c': 'Male_juv', 'column_d': 'Female_juv','column_e': 'Male_total', 'column_f': 'Female_adult'}, inplace=True)
tbl04_df_2014_usa.rename(columns={'column_a': 'State', 'column_b': 'Offense', 'column_c': 'white_juv', 'column_d': 'black_or_african_american_juv',
                                  'column_e': 'American_indian_or_Alska_native_juv', 'column_f': 'Asian_juv', 
                                  'column_g': 'Native_Hawaiian_orother_Pacific_Islander_juv','column_h': 'Total_juv',
                                  'column_i': 'white_adult', 'column_j': 'black_or_african_american_adult',
                                  'column_k': 'American_indian_or_Alska_native_adult', 'column_l': 'Asian_adult',
                                  'column_m': 'Native_Hawaiian_orother_Pacific_Islander_adult','column_n': 'Total_adult'}, inplace=True)
tbl05_df_2014_usa.rename(columns={'column_a': 'State', 'column_b': 'Offense', 'column_c': 'Hispanic_or_Latino_juv', 
                                  'column_d': 'Not_Hispanic_or_Latino_juv','column_e': 'Total_juv', 
                                  'column_f': 'Hispanic_or_Latino_adult', 'column_g': 'Not_Hispanic_or_Latino',
                                  'column_h': 'Total_adult'}, inplace=True)

#update Column names 2015 USA
tbl01_df_2015_usa.rename(columns={'state_state': 'State', 'commercial_sex_acts_offenses': 'offenses_Commercial_sex_act',
                                 'commercial_sex_acts_total_cleared': 'total_cleared_Commercial_sex_act', 'commercial_sex_acts_clearances_under_18': 'clearances_under_18_Commercial_sex_act',
                                 'involuntary_servitude_offenses': 'offenses_Involuntary_servitude', 'involuntary_servitude_total_cleared': 'total_cleared_Involuntary_servitude',
                                 'involuntary_servitude_clearances_under_18': 'clearances_under_18_Involuntary_servitude', 'total_offenses': 'offenses_total',
                                 'total_total_cleared': 'total_cleared_total', 'total_clearances_under_18': 'clearances_under_18_total'}, inplace=True)
tbl02_df_2015_usa.rename(columns={'state_state': 'State', 'offense_offense': 'Offense', 'juvenile_juvenile_male': 'Male_juv',
                                 'juvenile_juvenile_female': 'Female_juv', 'adult_adult_male': 'Male_total', 'adult_adult_female': 'Female_adult'}, inplace=True)
tbl03_df_2015_usa.rename(columns={'state_state': 'State', 'offense_offense': 'Offense', 'juvenile_white': 'white_juv',
                                  'juvenile_black_or_african_american': 'black_or_african_american_juv',
                                  'juvenile_american_indian_or_alaska_native': 'American_indian_or_Alska_native_juv',
                                  'juvenile_total': 'Total_juv', 'adult_white': 'white_adult',
                                  'adult_black_or_african_american': 'black_or_african_american_adult',
                                  'adult_american_indian_or_alaska_native': 'american_indian_or_alaska_native_adult',
                                  'adult_asian': 'Asian_adult', 'adult_total': 'Total_adult'}, inplace=True)
tbl03_df_2015_usa.rename(columns={'state_state': 'State', 'offense_offense': 'Offense', 
                                  'juvenile_hispanic_or_latino': 'Hispanic_or_Latino_juv',
                                  'juvenile_not_hispanic_or_latino': 'Not_Hispanic_or_Latino_juv',
                                  'juvenile_total': 'Total_juv', 'adult_hispanic_or_latino': 'Hispanic_or_Latino_adult',
                                  'adult_not_hispanic_or_latino': 'Not_Hispanic_or_Latino',
                                  'adult_total': 'Total_adult'}, inplace=True)

#update Column names 2016 USA
tbl01_df_2016_usa.rename(columns={'state_state': 'State', 'commercial_sex_acts_offenses': 'offenses_Commercial_sex_act',
                                 'commercial_sex_acts_total_cleared': 'total_cleared_Commercial_sex_act', 'commercial_sex_acts_clearances_under_18': 'clearances_under_18_Commercial_sex_act',
                                 'involuntary_servitude_offenses': 'offenses_Involuntary_servitude', 'involuntary_servitude_total_cleared': 'total_cleared_Involuntary_servitude',
                                 'involuntary_servitude_clearances_under_18': 'clearances_under_18_Involuntary_servitude', 'total_offenses': 'offenses_total',
                                 'total_total_cleared': 'total_cleared_total', 'total_clearances_under_18': 'clearances_under_18_total'}, inplace=True)
tbl02_df_2016_usa.rename(columns={'state_state': 'State', 'offense_offense': 'Offense', 'juvenile_juvenile_male': 'Male_juv',
                                 'juvenile_juvenile_female': 'Female_juv', 'adult_adult_male': 'Male_total', 'adult_adult_female': 'Female_adult'}, inplace=True)
tbl03_df_2016_usa.rename(columns={'state_state': 'State', 'offense_offense': 'Offense', 'juvenile_white': 'white_juv',
                                  'juvenile_black_or_african_american': 'black_or_african_american_juv',
                                  'juvenile_american_indian_or_alaska_native': 'American_indian_or_Alska_native_juv',
                                  'juvenile_total': 'Total_juv', 'adult_white': 'white_adult',
                                  'adult_black_or_african_american': 'black_or_african_american_adult',
                                  'adult_american_indian_or_alaska_native': 'american_indian_or_alaska_native_adult',
                                  'adult_asian': 'Asian_adult', 'adult_total': 'Total_adult'}, inplace=True)
tbl03_df_2016_usa.rename(columns={'state_state': 'State', 'offense_offense': 'Offense', 
                                  'juvenile_hispanic_or_latino': 'Hispanic_or_Latino_juv',
                                  'juvenile_not_hispanic_or_latino': 'Not_Hispanic_or_Latino_juv',
                                  'juvenile_total': 'Total_juv', 'adult_hispanic_or_latino': 'Hispanic_or_Latino_adult',
                                  'adult_not_hispanic_or_latino': 'Not_Hispanic_or_Latino',
                                  'adult_total': 'Total_adult'}, inplace=True)

# %%
# Dropping columns that have either value that is False or rows that have NaN value

# 2015 USA
tbl01_df_2015_usa.drop('clearances_under_18_Involuntary_servitude', axis=1, inplace=True)
tbl02_df_2015_usa.drop([48], axis=0, inplace=True)
tbl03_df_2015_usa = tbl03_df_2015_usa.drop([48], axis=0).drop(['juvenile_asian', 'juvenile_native_hawaiian_or_other_pacific_islander',
                                                               'adult_native_hawaiian_or_other_pacific_islander'], axis=1)
tbl04_df_2015_usa.drop([38,39], axis=0, inplace=True)

# 2016 USA
tbl01_df_2016_usa.drop('clearances_under_18_Involuntary_servitude', axis=1, inplace=True)
tbl02_df_2016_usa.drop([48], axis=0, inplace=True)
tbl03_df_2016_usa = tbl03_df_2016_usa.drop([48], axis=0).drop(['juvenile_asian', 'juvenile_native_hawaiian_or_other_pacific_islander',
                                                               'adult_native_hawaiian_or_other_pacific_islander'], axis=1)
tbl04_df_2016_usa.drop([38,39], axis=0, inplace=True)

# %% [markdown]
# ### 2013 UK Trafficking Data

# %%
country_of_referral_df_2013_uk['UID'] = country_of_referral_df_2013_uk.index
country_of_referral_df_2013_uk_drop = country_of_referral_df_2013_uk.drop([4])
country_of_referral_df_2013_uk_drop.head()

# %%
plt.figure(figsize=(10,7*0.5186))
temp_df = country_of_referral_df_2013_uk_drop.groupby(["Country of NRM referral"]).agg({"Female":"mean"}).reset_index()
print(temp_df.head())
ax_sns1 = sns.barplot(x = "Country of NRM referral",
            y="Female",
            data = country_of_referral_df_2013_uk_drop, 
            dodge = False,
            palette = "Set1",
            ci = None)
ax_sns1.set_title('Country of NRM referral 2013')
plt.show()

ax_sns1.figure.savefig("country_of_referral_df_2013_uk.png", dpi=150)

# %%
exploitation_type_df_2013_uk['UID'] = exploitation_type_df_2013_uk.index
exploitation_type_df_2013_uk = exploitation_type_df_2013_uk.drop([9, 10])
exploitation_type_df_2013_uk

# %%
plt.figure(figsize=(10,7*0.6186))
temp_df = exploitation_type_df_2013_uk.groupby(["Claimed exploitation Type"]).agg({"Total":"mean"}).reset_index()
print(temp_df.tail())
ax_sns2 = sns.barplot(x = "Claimed exploitation Type", 
            y="Total", 
            data = exploitation_type_df_2013_uk,
            dodge = False, 
            palette = "Set3", 
           ci = None)
ax_sns1.set_title('Claimed exploitation Type 2013')
plt.xticks(rotation=45)
plt.show()
ax_sns2.figure.savefig("exploitation_type_df_2013_uk.png", dpi=150)

# %% [markdown]
# ### 2015 UK Trafficking Data

# %%
country_of_referral_df_2015_uk['UID'] = country_of_referral_df_2015_uk.index
country_of_referral_df_2015_uk = country_of_referral_df_2015_uk.drop([4], axis=0)
country_of_referral_df_2015_uk.head()

# %%
plt.figure(figsize=(10,7*0.5186))
temp_df = country_of_referral_df_2015_uk.groupby(["Country of NRM referral"]).agg({"Adult":"mean"}).reset_index()
print(temp_df.head())
ax_sns1 = sns.barplot(x = "Country of NRM referral",
            y="Adult",
            data = country_of_referral_df_2015_uk, 
            dodge = False,
            palette = "Set1",
            ci = None)
ax_sns1.set_title('Country of NRM referral 2015 Adult')
plt.show()

ax_sns1.figure.savefig("country_of_referral_df_2015_uk.png", dpi=150)

# %%
plt.figure(figsize=(10,7*0.5186))
temp_df = country_of_referral_df_2015_uk.groupby(["Country of NRM referral Minor"]).agg({"Minor":"mean"}).reset_index()
print(temp_df.head())
ax_sns1 = sns.barplot(x = "Country of NRM referral",
            y="Minor",
            data = country_of_referral_df_2015_uk, 
            dodge = False,
            palette = "Set1",
            ci = None)
ax_sns1.set_title('Country of NRM referral 2015 Minor')
plt.show()

ax_sns1.figure.savefig("country_of_referral_df_2015_uk.png", dpi=150)

# %%
exploitation_type_df_2015_uk['UID'] = exploitation_type_df_2015_uk.index
exploitation_type_df_2015_uk = exploitation_type_df_2015_uk.drop([11], axis=0)
exploitation_type_df_2015_uk

# %%
plt.figure(figsize=(10,7*0.6186))
temp_df = exploitation_type_df_2015_uk.groupby(["Claimed exploitation Type"]).agg({"Total 2015":"mean"}).reset_index()
print(temp_df.tail())
ax_sns2 = sns.barplot(x = "Claimed exploitation Type", 
            y="Total 2015", 
            data = exploitation_type_df_2015_uk,
            dodge = False, 
            palette = "Set3", 
           ci = None)
ax_sns1.set_title('Claimed exploitation Type 2015')
plt.xticks(rotation=45)
plt.show()
ax_sns2.figure.savefig("exploitation_type_df_2015_uk.png", dpi=150)

# %%
referrals_all_df_2015_uk = referrals_all_df_2015_uk.drop([108], axis=0)
referrals_all_df_2015_uk = referrals_all_df_2015_uk[referrals_all_df_2015_uk['2015 Total'] > 5]

# %%
plt.figure(figsize=(10,7*0.6186))
temp_df = referrals_all_df_2015_uk.groupby(["Nationality/ Country of Origin"]).agg({"2015 Total":"mean"}).reset_index()
print(temp_df.tail())
ax_sns2 = sns.barplot(x = "Nationality/ Country of Origin", 
            y="2015 Total", 
            data = referrals_all_df_2015_uk,
            dodge = False, 
            palette = "Set3", 
           ci = None)
ax_sns1.set_title('Nationality/Country of Origin 2015')
plt.xticks(rotation=45)
plt.show()
ax_sns2.figure.savefig("Nationality_Country_of_Origin_2015.png", dpi=150)

# %% [markdown]
# ### 2016 UK Trafficking Data

# %%
country_of_referral_df_2016_uk['UID'] = country_of_referral_df_2016_uk.index
country_of_referral_df_2016_uk = country_of_referral_df_2016_uk.drop([4], axis=0)
country_of_referral_df_2016_uk.head()
# Out:
#   Country of NRM Referral  Adult  Minor  Total % of Total  \
# 0                England    2295   1204   3499        92%
# 1        Northern Ireland     27      6     33      0.90%
# 2               Scotland     103     47    150      3.90%
# 3                   Wales    102     21    123      3.20%
#
#   2015 - 2016 % Change  UID
# 0               19.20%    0
# 1              -37.70%    1
# 2                3.40%    2
# 3               -8.20%    3

# %%
plt.figure(figsize=(10,7*0.5186))
temp_df = country_of_referral_df_2016_uk.groupby(["Country of NRM Referral"]).agg({"Adult":"mean"}).reset_index()
print(temp_df.head())
ax_sns1 = sns.barplot(x = "Country of NRM Referral",
            y="Adult",
            data = country_of_referral_df_2016_uk, 
            dodge = False,
            palette = "Set1",
            ci = None)
ax_sns1.set_title('Country of NRM referral 2016 Adult')
plt.show()

ax_sns1.figure.savefig("country_of_referral_df_2016_uk.png", dpi=150)
# Out:
#   Country of NRM Referral  Adult
# 0                England    2295
# 1        Northern Ireland     27
# 2               Scotland     103
# 3                   Wales    102

# %%
plt.figure(figsize=(10,7*0.5186))
temp_df = country_of_referral_df_2016_uk.groupby(["Country of NRM Referral"]).agg({"Adult":"mean"}).reset_index()
print(temp_df.head())
ax_sns1 = sns.barplot(x = "Country of NRM Referral",
            y="Minor",
            data = country_of_referral_df_2016_uk, 
            dodge = False,
            palette = "Set1",
            ci = None)
ax_sns1.set_title('Country of NRM referral 2016 Minor')
plt.show()

ax_sns1.figure.savefig("country_of_referral_df_2016_uk.png", dpi=150)
# Out:
#   Country of NRM Referral  Adult
# 0                England    2295
# 1        Northern Ireland     27
# 2               Scotland     103
# 3                   Wales    102

# %%
exploitation_type_df_2016_uk['UID'] = exploitation_type_df_2016_uk.index
exploitation_type_df_2016_uk = exploitation_type_df_2016_uk.drop([10], axis=0)
exploitation_type_df_2016_uk
# Out:
#                        Claimed Exploitation Type  Female  Male  Trans- gender  \
# 0                     Adult - Domestic Servitude     259    67              0
# 1                    Adult - Labour Exploitation     182   925              0
# 2                       Adult - Organ Harvesting       1     0              0
# 3                    Adult - Sexual Exploitation     888    58              5
# 4                   Adult - Unknown Exploitation      70    72              0
# 5                     Minor - Domestic Servitude      67    36              0
# 6                    Minor - Labour Exploitation      68   400              0
# 7  Minor - Sexual Exploitation (non-UK national)     118    29              0
# 8      Minor - Sexual Exploitation (UK national)     203    12              0
# 9                   Minor - Unknown Exploitation      80   265              0
#
#    Total 2016 2015 - 2016 % Change  UID
# 0         326               -7.60%    0
# ...

# %%
plt.figure(figsize=(10,7*0.6186))
temp_df = exploitation_type_df_2016_uk.groupby(["Claimed Exploitation Type"]).agg({"Total 2016":"mean"}).reset_index()
print(temp_df.tail())
ax_sns2 = sns.barplot(x = "Claimed Exploitation Type", 
            y="Total 2016", 
            data = exploitation_type_df_2016_uk,
            dodge = False, 
            palette = "Set3", 
           ci = None)
ax_sns1.set_title('Claimed exploitation Type 2016')
plt.xticks(rotation=45)
plt.show()
ax_sns2.figure.savefig("exploitation_type_df_2016_uk.png", dpi=150)
# Out:
#                        Claimed Exploitation Type  Total 2016
# 5                     Minor - Domestic Servitude         103
# 6                    Minor - Labour Exploitation         468
# 7      Minor - Sexual Exploitation (UK national)         215
# 8  Minor - Sexual Exploitation (non-UK national)         147
# 9                   Minor - Unknown Exploitation         345

# %%
referrals_all_df_2016_uk = referrals_all_df_2016_uk.drop([111], axis=0)
referrals_all_df_2016_uk = referrals_all_df_2016_uk[referrals_all_df_2016_uk['2016 Total'] > 5]

# %%
plt.figure(figsize=(10,7*0.6186))
temp_df = referrals_all_df_2016_uk.groupby(["Nationality/ Country of Origin"]).agg({"2016 Total":"mean"}).reset_index()
print(temp_df.tail())
ax_sns2 = sns.barplot(x = "Nationality/ Country of Origin", 
            y="2016 Total", 
            data = referrals_all_df_2016_uk,
            dodge = False, 
            palette = "Set3", 
           ci = None)
ax_sns1.set_title('Nationality/Country of Origin 2016')
plt.xticks(rotation=45)
plt.show()
ax_sns2.figure.savefig("Nationality_Country_of_Origin_2016.png", dpi=150)
# Out:
#    Nationality/ Country of Origin  2016 Total
# 44                 United Kingdom         326
# 45       United States of America           6
# 46                        Vietnam         519
# 47                         Zambia           7
# 48                       Zimbabwe          19

# %%
tbl01_df_2015_usa

# %%
tbl02_df_2015_usa

# %%
tbl03_df_2015_usa

# %%
tbl04_df_2015_usa
